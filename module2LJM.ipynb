# %% [markdown]
# <a href="https://colab.research.google.com/github/luismadri08/skills-introduction-to-github/blob/main/module2LJM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXERCICIO 1

# %%
x=2
y=3
print('x=', x)
print('value of ', x, '+', x, 'is',(x+x) )
print((x+y))

name = input('what is your name?')
print('your name is: ', name)


area= 0
ratio= int(input('whats the radio of circle: '))
area= 3.141516 * ratio**2
print('the area of the circle: ', area)
# Out:
# x= 2
# value of  2 + 2 is 4
# 5
# what is your name?luis
# your name is:  luis
# whats the radio of circle: 3
# the area of the circle:  28.273644
