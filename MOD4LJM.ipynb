# %% [markdown]
# <a href="https://colab.research.google.com/github/luismadri08/skills-introduction-to-github/blob/main/MOD4LJM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SUM OF EVERY I IN THE LST

# %%
lst= [1,2,3,4,5]
sum_total= 0
for n in lst:
  sum_total+=n
print(sum_total)
# Out:
# 15

# %% [markdown]
# check if number is found

# %%
lst= [1,2,3,4,5,6,7,8]

num_check =int(input("what is the number u want to check: "))

for n in lst:
  if n!=num_check:
    print("invalid input")
    i+=0
  else:
   print("number found ")
# Out:
# what is the number u want to check: 8
# invalid input
# invalid input
# invalid input
# invalid input
# invalid input
# invalid input
# invalid input
# number found

# %% [markdown]
# two arguments added and printed (name age)

# %%
name= "uno"
age= 000
def persona(name, age):
  return(persona)
print("name: " , name, "age: ",age)
# Out:
# name:  uno age:  0
