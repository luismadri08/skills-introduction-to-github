# %% [markdown]
# <a href="https://colab.research.google.com/github/luismadri08/skills-introduction-to-github/blob/main/loggin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
key = "CUNYhhMM123" #password
def login (key):
  attempts = 3
  while attempts > 0:
   inp= input("what is your password: ") #input
   if inp!= key:
    print("your password is incorrect, try again")
    attempts-=1
   else:
      print("logged in")
      return
login(key)
# Out:
# what is your password: CUNYhhMM123
# logged in

# %% [markdown]
# simulate a login system.
#
# user have 3 tries.
# U
# key=password (letters and numbers mix
# A password is a key, if inserted must print "pass correct.
# if statement to check if password is correct or incorrect
#
#
# P
# have a ramdom key which simulates the key.
# a for loop only <3 # of tries
# ask the user(input) to type the exact key.
# if password is correct (input== key) print login.
#
#
# I
# key= "12345":
# def loggin( key):
